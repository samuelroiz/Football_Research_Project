# %%
import pandas as pd
import numpy as np

# %%
transfer_df = pd.read_csv('../Sven_football/transfers.csv')
transfer_df.head()
# Out:
#                 Name        Position  Age     Team_from     League_from  \
# 0          Luís Figo    Right Winger   27  FC Barcelona          LaLiga
# 1      Hernán Crespo  Centre-Forward   25         Parma         Serie A
# 2      Marc Overmars     Left Winger   27       Arsenal  Premier League
# 3  Gabriel Batistuta  Centre-Forward   31    Fiorentina         Serie A
# 4     Nicolas Anelka  Centre-Forward   21   Real Madrid          LaLiga
#
#         Team_to League_to     Season  Market_value  Transfer_fee
# 0   Real Madrid    LaLiga  2000-2001           NaN      60000000
# 1         Lazio   Serie A  2000-2001           NaN      56810000
# 2  FC Barcelona    LaLiga  2000-2001           NaN      40000000
# 3       AS Roma   Serie A  2000-2001           NaN      36150000
# 4      Paris SG   Ligue 1  2000-2001           NaN      34500000

# %%
        
transfer_df["Country_from"] = transfer_df["League_from"]
transfer_df.loc[transfer_df["Country_from"] =="LaLiga","Country_from"]="Spain"
transfer_df.loc[transfer_df["Country_from"] =="LaLiga2","Country_from"]="Spain"
transfer_df.loc[transfer_df["Country_from"] =="Serie A","Country_from"]="Italy"
transfer_df.loc[transfer_df["Country_from"] =="2.Bundesliga","Country_from"]="Germany"
transfer_df.loc[transfer_df["Country_from"] =="1.Bundesliga","Country_from"]="Germany"
transfer_df.loc[transfer_df["Country_from"] =="Championship","Country_from"]="England"
transfer_df.loc[transfer_df["Country_from"] =="Premier League","Country_from"]="England"

transfer_df
# Out:
#                    Name            Position  Age       Team_from  \
# 0             Luís Figo        Right Winger   27    FC Barcelona
# 1         Hernán Crespo      Centre-Forward   25           Parma
# 2         Marc Overmars         Left Winger   27         Arsenal
# 3     Gabriel Batistuta      Centre-Forward   31      Fiorentina
# 4        Nicolas Anelka      Centre-Forward   21     Real Madrid
# ...                 ...                 ...  ...             ...
# 4695      Jasmin Kurtic  Attacking Midfield   29        Atalanta
# 4696          Tchê Tchê    Central Midfield   25       Palmeiras
# 4697      Silvan Widmer          Right-Back   25  Udinese Calcio
# 4698         Yuya Osako      Second Striker   28      1. FC Köln
# 4699       Kyle Bartley         Centre-Back   27         Swansea
#
#          League_from        Team_to     League_to     Season  Market_value  \
# 0             LaLiga    Real Madrid        LaLiga  2000-2001           NaN
# ...
